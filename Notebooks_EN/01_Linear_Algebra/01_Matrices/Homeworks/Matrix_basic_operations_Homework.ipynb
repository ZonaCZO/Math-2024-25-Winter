# %% [markdown]
# 1. Calculate the sum of matrices $A = \begin{pmatrix} 1 & 2 \\ 3 & 4 \end{pmatrix} \ and \ B = \begin{pmatrix} 5 & 6 \\ 7 & 8 \end{pmatrix}$.
#
# $
# A + B = \begin{pmatrix} 1 & 2 \\ 3 & 4 \end{pmatrix} + \begin{pmatrix} 5 & 6 \\ 7 & 8 \end{pmatrix} = \begin{pmatrix} 1 + 5 & 2 + 6 \\ 3 + 7 & 4 + 8 \end{pmatrix} = \begin{pmatrix} 6 & 8 \\ 10 & 12 \end{pmatrix}
# $

# %%
# 1
import sympy as sp

A=sp.Matrix([[1,2],[3,4]])
B=sp.Matrix([[5,6],[7,8]])
A # display matrix A
# Out:
# Matrix([
# [1, 2],
# [3, 4]])

# %%
B # display matrix B
# Out:
# Matrix([
# [5, 6],
# [7, 8]])

# %%
A+B # verify matrix addition
# Out:
# Matrix([
# [ 6,  8],
# [10, 12]])

# %% [markdown]
# 2.
# Calculate the product of matrix and scalar (k)
#
# $$
# A = \begin{pmatrix} 4 & 2 \\ 12 & 4 \end{pmatrix}, \quad k = \frac{1}{4}
# $$
#
# Multiply each element of the matrix by a scalar \( k \):
#
# $$
# kA = \frac{1}{4} \begin{pmatrix} 4 & 2 \\ 12 & 4 \end{pmatrix} = \begin{pmatrix} \frac{1}{4} \times 4 & \frac{1}{4} \times 2 \\ \frac{1}{4} \times 12 & \frac{1}{4} \times 4 \end{pmatrix}
# $$
#
# Result:
#
# $$
# kA = \begin{pmatrix} 1 & 0.5 \\ 3 & 1 \end{pmatrix}
# $$

# %%
# 2
import sympy as sp
A = sp.Matrix([[4, 2], [12, 4]])
k = 1/4

# Calculate the product of matrix A and scalar k
product = k * A
product
# Out:
# Matrix([
# [1.0, 0.5],
# [3.0, 1.0]])

# %% [markdown]
# 3. Calculate the products $A \cdot B \ and \ B \cdot A \ for matrices \ A = \begin{pmatrix} 3 & 2 \\ 2 & 4 \end{pmatrix} \ and \ B = \begin{pmatrix} 4 & 1 \\ 6 & 4 \end{pmatrix} $.
#
# $
# A \cdot B = \begin{pmatrix} 3 & 2 \\ 2 & 4 \end{pmatrix} \cdot \begin{pmatrix} 4 & 1 \\ 6 & 4 \end{pmatrix} = \begin{pmatrix} (3 \cdot 4 + 2 \cdot 6) & (3 \cdot 1 + 2 \cdot 4) \\ (2 \cdot 4 + 4 \cdot 6) & (2 \cdot 1 + 4 \cdot 4) \end{pmatrix} = \begin{pmatrix} 24 & 11 \\ 32 & 18 \end{pmatrix}
# $
#
# $
# B \cdot A = \begin{pmatrix} 4 & 1 \\ 6 & 4 \end{pmatrix} \cdot \begin{pmatrix} 3 & 2 \\ 2 & 4 \end{pmatrix} = \begin{pmatrix} (4 \cdot 3 + 1 \cdot 2) & (4 \cdot 2 + 1 \cdot 4) \\ (6 \cdot 3 + 4 \cdot 2) & (6 \cdot 2 + 4 \cdot 4) \end{pmatrix} = \begin{pmatrix} 14 & 12 \\ 26 & 28 \end{pmatrix}
# $

# %%
# 3
import sympy as sp
A = sp.Matrix([[3, 2], [2, 4]])
и = sp.Matrix([[4, 1], [6, 4]])


product = A * B
product
# Out:
# Matrix([
# [29, 34],
# [38, 44]])

# %%
product = B * A
product
# Out:
# Matrix([
# [27, 34],
# [37, 46]])
